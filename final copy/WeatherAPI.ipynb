# %% [markdown]
# # WeatherPy
# ----
#
# ## Analysis
# * Intuition is justified here, as the temperature indeed does become warmer as the latitude nears 0.
# * Cloudiness, at first glance, doesn't seem to have any sort of relationship with latitude. However, while the association is loose one can peer closely and see that high levels of cloudiness don't occur as frequently near the equator. Perhaps the intense sunlight acts to disperse clouds?
# * Humidity does not seem to have a strong relationship with latitude. It's likelty that altitude and proximity to the sea is more important. There were a couple entries with over 300% humidity.
#
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
cities
# Out:
# ['sokolka',
#  'ushuaia',
#  'faanui',
#  'kahului',
#  'moerai',
#  'dungarpur',
#  'tilichiki',
#  'clyde river',
#  'hithadhoo',
#  'porto novo',
#  'asyut',
#  'tuktoyaktuk',
#  'las palmas',
#  'bluff',
#  'nikolskoye',
#  'kopyevo',
#  'iqaluit',
#  'mataura',
#  'bonfim',
#  'bracebridge',
#  'port alfred',
#  'port moresby',
#  'rocha',
#  'dikson',
#  'sinnamary',
#  'barrow',
#  'qaanaaq',
#  'albany',
#  'cidreira',
#  'hermanus',
#  'jamestown',
#  'kodiak',
#  'chernyshevskiy',
#  'vaitupu',
#  'tara',
#  'alvorada',
#  'pangody',
#  'isangel',
#  'east london',
#  'muroto',
#  'consolacion del sur',
#  'ituni',
#  'punta arenas',
#  'lorengau',
#  'severo-kurilsk',
#  'sakakah',
#  'lang son',
#  'victoria',
#  'araouane',
#  'rikitea',
#  'grand river south east',
#  'norman wells',
#  'vaini',
#  'cape town',
#  'bathsheba',
#  'zhigansk',
#  'ondjiva',
#  'naze',
#  'ketchikan',
#  'sitka',
#  'kapaa',
#  'honiara',
#  'weligama',
#  'mujiayingzi',
#  'qasigiannguit',
#  'gaoyou',
#  'lichtenburg',
#  'san carlos de bariloche',
#  'perelyub',
#  'provideniya',
#  'barentsburg',
#  'barela',
#  'warqla',
#  'san patricio',
#  'aksu',
#  'vanavara',
#  'caravelas',
#  'iracoubo',
#  'kassala',
#  'palana',
#  'were ilu',
#  'manuk mangkaw',
#  'fevralsk',
#  'illoqqortoormiut',
#  'broome',
#  'bam',
#  'lompoc',
#  'hobart',
#  'ribeira grande',
#  'calbuco',
#  'sitio novo do tocantins',
#  'camacha',
#  'boguchany',
#  'nosivka',
#  'busselton',
#  'khatanga',
#  'nova olinda do norte',
#  'avarua',
#  'rio de janeiro',
#  'shingu',
#  'bouake',
#  'atuona',
#  'airai',
#  'palabuhanratu',
#  'lasa',
#  'saint george',
#  'new norfolk',
#  'chokurdakh',
#  'quechultenango',
#  'kidal',
#  'ondorhaan',
#  'la ronge',
#  'nantucket',
#  'tessalit',
#  'upernavik',
#  'tsabong',
#  'phumi samraong',
#  'linxia',
#  'geraldton',
#  'sao gabriel da cachoeira',
#  'yellowknife',
#  'mar del plata',
#  'castro',
#  'amderma',
#  'belushya guba',
#  'arraial do cabo',
#  'kununurra',
#  'houston',
#  'temaraia',
#  'saint-philippe',
#  'bethel',
#  'hilo',
#  'ponta do sol',
#  'bambous virieux',
#  'sao filipe',
#  'aflu',
#  'puerto escondido',
#  'tasiilaq',
#  'thompson',
#  'carnarvon',
#  'antalaha',
#  'longyearbyen',
#  'taolanaro',
#  'port lincoln',
#  'zhigalovo',
#  'anju',
#  'taksimo',
#  'fasa',
#  'kendari',
#  'cansancao',
#  'bredasdorp',
#  'lebu',
#  'vestmannaeyjar',
#  'tiarei',
#  'asau',
#  'baykit',
#  'port augusta',
#  'atambua',
#  'kaitangata',
#  'sayyan',
#  'khakhea',
#  'kaeo',
#  'batemans bay',
#  'bengkulu',
#  'macaboboni',
#  'ngukurr',
#  'sentyabrskiy',
#  'jeremie',
#  'leningradskiy',
#  'port blair',
#  'attawapiskat',
#  'puerto ayora',
#  'chorozinho',
#  'chuy',
#  'yumen',
#  'kayerkan',
#  'puerto del rosario',
#  'haines junction',
#  'maniitsoq',
#  'betsiamites',
#  'verkhoyansk',
#  'olafsvik',
#  'sambava',
#  'adrar',
#  'bintulu',
#  'khonuu',
#  'asfi',
#  'saskylakh',
#  'belyy',
#  'port elizabeth',
#  'saint-louis',
#  'huarmey',
#  'morgan city',
#  'turayf',
#  'mopipi',
#  'shiyan',
#  'bardiyah',
#  'waipawa',
#  'maonon',
#  'mantua',
#  'morant bay',
#  'aloleng',
#  'labuhan',
#  'stromness',
#  'santa lucia',
#  'umzimvubu',
#  'tiksi',
#  'mount gambier',
#  'beyneu',
#  'honningsvag',
#  'danane',
#  'lagoa',
#  'keratea',
#  'srandakan',
#  'yeppoon',
#  'camargo',
#  'plaster rock',
#  'borama',
#  'wainwright',
#  'san cristobal',
#  'margate',
#  'lovozero',
#  'dingle',
#  'xichang',
#  'farafangana',
#  'vila franca do campo',
#  'aykhal',
#  'natal',
#  'katsuura',
#  'nizhneyansk',
#  'wajima',
#  'grindavik',
#  'neumunster',
#  'nyamuswa',
#  'lavrentiya',
#  'laje',
#  'butaritari',
#  'elliot lake',
#  'kalmunai',
#  'rungata',
#  'orocue',
#  'necochea',
#  'samusu',
#  'maykain',
#  'san rafael',
#  'suntar',
#  'sioux lookout',
#  'algeciras',
#  'shimoda',
#  'klaksvik',
#  'sao joao da barra',
#  'boshnyakovo',
#  'fuxin',
#  'palmer',
#  'solnechnyy',
#  'kelo',
#  'kamina',
#  'udachnyy',
#  'tabou',
#  'mys shmidta',
#  'vila velha',
#  'avera',
#  'los llanos de aridane',
#  'kruisfontein',
#  'kenai',
#  'teeli',
#  'sakhipur',
#  'cabo san lucas',
#  'ahipara',
#  'hailar',
#  'stolin',
#  'saint-joseph',
#  'razole',
#  'whyalla',
#  'ilulissat',
#  'aliaga',
#  'roma',
#  'tabiauea',
#  'krasnoborsk',
#  'rawson',
#  'chapais',
#  'college',
#  'rio tuba',
#  'kinsale',
#  'arauca',
#  'san jeronimo',
#  'monrovia',
#  'grand gaube',
#  'yenagoa',
#  'mnogovershinnyy',
#  'basse',
#  'tocache',
#  'coquimbo',
#  'biak',
#  'pacifica',
#  'esperance',
#  'cururupu',
#  'sandakan',
#  'edgewater',
#  'codrington',
#  'mariestad',
#  'narsaq',
#  'correderos',
#  'dwarka',
#  'tsihombe',
#  'kracheh',
#  'vung tau',
#  'tura',
#  'ongwediva',
#  'gravdal',
#  'ishigaki',
#  'jinxiang',
#  'marsa matruh',
#  'usinsk',
#  'meadow lake',
#  'skrunda',
#  'rio cuarto',
#  'satitoa',
#  'pushkino',
#  'fare',
#  'hobyo',
#  'upington',
#  'kokopo',
#  'carndonagh',
#  'nuuk',
#  'elat',
#  'tuatapere',
#  'cherskiy',
#  'ngunguru',
#  'verkhnyaya toyma',
#  'faya',
#  'pimentel',
#  'zaraza',
#  'makakilo city',
#  'touros',
#  'awjilah',
#  'areosa',
#  'maunabo',
#  'druskininkai',
#  'mazagao',
#  'anadyr',
#  'atasu',
#  'mananjary',
#  'hakkari',
#  'igrim',
#  'mildura',
#  'madimba',
#  'tosno',
#  'lexington',
#  'alofi',
#  'kismayo',
#  'florianopolis',
#  'liancheng',
#  'manokwari',
#  'kamenskoye',
#  'taoudenni',
#  'mbacke',
#  'akyab',
#  'talnakh',
#  'tidore',
#  'okhotsk',
#  'flinders',
#  'dunedin',
#  'parana',
#  'ulagan',
#  'vardo',
#  'gamba',
#  'pevek',
#  'praia da vitoria',
#  'ipora',
#  'kamaishi',
#  'cayenne',
#  'mehamn',
#  'anar darreh',
#  'paita',
#  'birao',
#  'karratha',
#  'coihaique',
#  'souris',
#  'mon',
#  'souillac',
#  'nabire',
#  'san jose',
#  'sahuaripa',
#  'balykshi',
#  'warrenton',
#  'nanortalik',
#  'burewala',
#  'jalu',
#  'altay',
#  'te anau',
#  'ilhabela',
#  'laguna',
#  'miyako',
#  'katobu',
#  'sangar',
#  'russell',
#  'busilac',
#  'fairbanks',
#  'korla',
#  'georgetown',
#  'merauke',
#  'beloha',
#  'manaure',
#  'vostok',
#  'saint-pierre',
#  'alice springs',
#  'boyolangu',
#  'rincon',
#  'ambilobe',
#  'oranjemund',
#  'kondinskoye',
#  'guerrero negro',
#  'kangaatsiaq',
#  'nome',
#  'australind',
#  'lolua',
#  'jaru',
#  'sharjah',
#  'guarapari',
#  'tevriz',
#  'deqing',
#  'ohangaron',
#  'manzil salim',
#  'tabas',
#  'matadi',
#  'atar',
#  'saryshagan',
#  'najran',
#  'sosva',
#  'luvianos',
#  'portachuelo',
#  'batagay-alyta',
#  'hofn',
#  'lima',
#  'saleaula',
#  'seoul',
#  'shawnee',
#  'kulachi',
#  'oskemen',
#  'tres arroyos',
#  'mahebourg',
#  'ontario',
#  'mahibadhoo',
#  'halalo',
#  'springville',
#  'nushki',
#  'leh',
#  'sal rei',
#  'olinda',
#  'miramar',
#  'sorland',
#  'sulangan',
#  'hirado',
#  'waitati',
#  'sooke',
#  'guozhen',
#  'conde',
#  'mana',
#  'okha',
#  'magog',
#  'marzuq',
#  'kavaratti',
#  'constitucion',
#  'ostrogozhsk',
#  'novobureyskiy',
#  'caconda',
#  'nioro',
#  'onega',
#  'catalina',
#  'kalmar',
#  'roald',
#  'toppenish',
#  'poum',
#  'fortuna',
#  'grimshaw',
#  'arcata',
#  'high rock',
#  'deputatskiy',
#  'crotone',
#  'kavieng',
#  'chengannur',
#  'jiehu',
#  'kalaleh',
#  'rangapara',
#  'port huron',
#  'nizwa',
#  'antsohihy',
#  'singaparna',
#  'radchenko',
#  'comodoro rivadavia',
#  'myitkyina',
#  'bangassou',
#  'tacuati',
#  'koumac',
#  'bajo baudo',
#  'yulara',
#  'teahupoo',
#  'tromso',
#  'acapulco',
#  'aporawan',
#  'daxian',
#  'otofuke',
#  'trelew',
#  'otane',
#  'markala',
#  'oil city',
#  'xiongzhou',
#  'sisimiut',
#  'omsukchan',
#  'mahanoro',
#  'yomou',
#  'buala',
#  'wattegama',
#  'pacific grove',
#  'thouars',
#  'sydney',
#  'murray bridge',
#  'calama',
#  'bilma',
#  'salalah',
#  'liwale',
#  'hokitika',
#  'hasaki',
#  'kalugumalai',
#  'rostaq',
#  'cabinda',
#  'sistranda',
#  'buin',
#  'muzaffarpur',
#  'bogo',
#  'tete',
#  'surenavan',
#  'nacunday',
#  'bad freienwalde',
#  'rio grande',
#  'srednekolymsk',
#  'torbay',
#  'charagua',
#  'kankan',
#  'bargal',
#  'montecristo',
#  'sotnikovo',
#  'pangkalanbuun',
#  'nam som',
#  'port hardy',
#  'belyy yar',
#  'rio gallegos',
#  'general roca',
#  'pangnirtung',
#  'coria',
#  'vayia',
#  'balabac',
#  'whithorn',
#  'chase',
#  'hay river',
#  'samalaeulu',
#  'mmabatho',
#  'inhambane',
#  'amguri',
#  'fuerte olimpo',
#  'gulshat',
#  'centralia',
#  'krasnovishersk',
#  'praia',
#  'ludvika',
#  'taikang',
#  'samana',
#  'namatanai',
#  'hlotse',
#  'half moon bay',
#  'ponta delgada',
#  'kautokeino',
#  'myrtle beach',
#  'puro',
#  'kalmanka',
#  'verkhnyaya inta',
#  'hualmay',
#  'maghama',
#  'san andres',
#  'port lavaca',
#  'sao jose da coroa grande',
#  'mitsamiouli',
#  'nam tha',
#  'panagjuriste',
#  'madingou',
#  'padilla',
#  'naas',
#  'basco',
#  'hamilton',
#  'altoona',
#  'cairns',
#  'saint-francois',
#  'pakwach',
#  'nha trang',
#  'urumqi',
#  'tezu',
#  'mercedes',
#  'mokrous',
#  'calvinia',
#  'umm lajj',
#  'bilibino',
#  'portpatrick',
#  'kutum',
#  'kovur',
#  'ocos',
#  'cruzeiro do sul']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.


url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
api_key = "9d685dea3c99b3a25afb99d8a3ffe4b6"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
citydict = []

cityname = []
cloud = []
country = []
date = []
humid = []
lat = []
lng = []
maxtemp = []
windspeed = []

counter = 1
setnum = 1
print("Beginning Data Retrieval")
print("------------------------")

# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    print(f"Processing Record {counter} of Set {setnum} | {city}")
    
    counter = counter + 1
    
    response = requests.get(query_url + city)
    data = response.json()
    
    if(response.status_code == 200):
        
        cityname.append(data["name"])
        cloud.append(data["clouds"]["all"])
        country.append(data["sys"]["country"])
        date.append(data["dt"])
        humid.append(data["main"]["humidity"])
        lat.append(data["coord"]["lat"])
        lng.append(data["coord"]["lon"])
        maxtemp.append(data["main"]["temp_max"])
        windspeed.append(data["wind"]["speed"])
        
        citydict = {"City": cityname,
                    "Cloudiness": cloud,
                    "Country": country,
                    "Date": date,
                    "Humidity": humid,
                    "Lat": lat,
                    "Lng": lng,
                    "Max Temp": maxtemp,
                    "Wind Speed": windspeed}
       
    else:
        print(f"City:{city} was not found. | Retrieving data for next entry.")
        setnum = setnum + 1
    time.sleep(1)
   

print("--------------------------")
print("Data Retrieval is Complete")
print("--------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | sokolka
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | kahului
# Processing Record 5 of Set 1 | moerai
# Processing Record 6 of Set 1 | dungarpur
# Processing Record 7 of Set 1 | tilichiki
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | porto novo
# Processing Record 11 of Set 1 | asyut
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | las palmas
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | kopyevo
# City:kopyevo was not found. | Retrieving data for next entry.
# Processing Record 17 of Set 2 | iqaluit
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | bonfim
# Processing Record 20 of Set 2 | bracebridge
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | port moresby
# Processing Record 23 of Set 2 | rocha
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | sinnamary
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | hermanus
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | chernyshevskiy
# Processing Record 34 of Set 2 | vaitupu
# City:vaitupu was not found. | Retrieving data for next entry.
# Processing Record 35 of Set 3 | tara
# Processing Record 36 of Set 3 | alvorada
# Processing Record 37 of Set 3 | pangody
# Processing Record 38 of Set 3 | isangel
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | muroto
# Processing Record 41 of Set 3 | consolacion del sur
# Processing Record 42 of Set 3 | ituni
# City:ituni was not found. | Retrieving data for next entry.
# Processing Record 43 of Set 4 | punta arenas
# Processing Record 44 of Set 4 | lorengau
# Processing Record 45 of Set 4 | severo-kurilsk
# Processing Record 46 of Set 4 | sakakah
# City:sakakah was not found. | Retrieving data for next entry.
# Processing Record 47 of Set 5 | lang son
# Processing Record 48 of Set 5 | victoria
# Processing Record 49 of Set 5 | araouane
# Processing Record 50 of Set 5 | rikitea
# Processing Record 51 of Set 5 | grand river south east
# City:grand river south east was not found. | Retrieving data for next entry.
# Processing Record 52 of Set 6 | norman wells
# Processing Record 53 of Set 6 | vaini
# Processing Record 54 of Set 6 | cape town
# Processing Record 55 of Set 6 | bathsheba
# Processing Record 56 of Set 6 | zhigansk
# Processing Record 57 of Set 6 | ondjiva
# Processing Record 58 of Set 6 | naze
# Processing Record 59 of Set 6 | ketchikan
# Processing Record 60 of Set 6 | sitka
# Processing Record 61 of Set 6 | kapaa
# Processing Record 62 of Set 6 | honiara
# Processing Record 63 of Set 6 | weligama
# Processing Record 64 of Set 6 | mujiayingzi
# Processing Record 65 of Set 6 | qasigiannguit
# Processing Record 66 of Set 6 | gaoyou
# Processing Record 67 of Set 6 | lichtenburg
# Processing Record 68 of Set 6 | san carlos de bariloche
# Processing Record 69 of Set 6 | perelyub
# Processing Record 70 of Set 6 | provideniya
# Processing Record 71 of Set 6 | barentsburg
# City:barentsburg was not found. | Retrieving data for next entry.
# Processing Record 72 of Set 7 | barela
# Processing Record 73 of Set 7 | warqla
# City:warqla was not found. | Retrieving data for next entry.
# Processing Record 74 of Set 8 | san patricio
# Processing Record 75 of Set 8 | aksu
# Processing Record 76 of Set 8 | vanavara
# Processing Record 77 of Set 8 | caravelas
# Processing Record 78 of Set 8 | iracoubo
# Processing Record 79 of Set 8 | kassala
# Processing Record 80 of Set 8 | palana
# Processing Record 81 of Set 8 | were ilu
# Processing Record 82 of Set 8 | manuk mangkaw
# Processing Record 83 of Set 8 | fevralsk
# City:fevralsk was not found. | Retrieving data for next entry.
# Processing Record 84 of Set 9 | illoqqortoormiut
# City:illoqqortoormiut was not found. | Retrieving data for next entry.
# Processing Record 85 of Set 10 | broome
# Processing Record 86 of Set 10 | bam
# Processing Record 87 of Set 10 | lompoc
# Processing Record 88 of Set 10 | hobart
# Processing Record 89 of Set 10 | ribeira grande
# Processing Record 90 of Set 10 | calbuco
# Processing Record 91 of Set 10 | sitio novo do tocantins
# City:sitio novo do tocantins was not found. | Retrieving data for next entry.
# Processing Record 92 of Set 11 | camacha
# Processing Record 93 of Set 11 | boguchany
# Processing Record 94 of Set 11 | nosivka
# Processing Record 95 of Set 11 | busselton
# Processing Record 96 of Set 11 | khatanga
# Processing Record 97 of Set 11 | nova olinda do norte
# Processing Record 98 of Set 11 | avarua
# Processing Record 99 of Set 11 | rio de janeiro
# Processing Record 100 of Set 11 | shingu
# Processing Record 101 of Set 11 | bouake
# Processing Record 102 of Set 11 | atuona
# Processing Record 103 of Set 11 | airai
# Processing Record 104 of Set 11 | palabuhanratu
# City:palabuhanratu was not found. | Retrieving data for next entry.
# Processing Record 105 of Set 12 | lasa
# Processing Record 106 of Set 12 | saint george
# Processing Record 107 of Set 12 | new norfolk
# Processing Record 108 of Set 12 | chokurdakh
# Processing Record 109 of Set 12 | quechultenango
# Processing Record 110 of Set 12 | kidal
# Processing Record 111 of Set 12 | ondorhaan
# City:ondorhaan was not found. | Retrieving data for next entry.
# Processing Record 112 of Set 13 | la ronge
# Processing Record 113 of Set 13 | nantucket
# Processing Record 114 of Set 13 | tessalit
# Processing Record 115 of Set 13 | upernavik
# Processing Record 116 of Set 13 | tsabong
# Processing Record 117 of Set 13 | phumi samraong
# City:phumi samraong was not found. | Retrieving data for next entry.
# Processing Record 118 of Set 14 | linxia
# Processing Record 119 of Set 14 | geraldton
# Processing Record 120 of Set 14 | sao gabriel da cachoeira
# Processing Record 121 of Set 14 | yellowknife
# Processing Record 122 of Set 14 | mar del plata
# Processing Record 123 of Set 14 | castro
# Processing Record 124 of Set 14 | amderma
# City:amderma was not found. | Retrieving data for next entry.
# Processing Record 125 of Set 15 | belushya guba
# City:belushya guba was not found. | Retrieving data for next entry.
# Processing Record 126 of Set 16 | arraial do cabo
# Processing Record 127 of Set 16 | kununurra
# Processing Record 128 of Set 16 | houston
# Processing Record 129 of Set 16 | temaraia
# City:temaraia was not found. | Retrieving data for next entry.
# Processing Record 130 of Set 17 | saint-philippe
# Processing Record 131 of Set 17 | bethel
# Processing Record 132 of Set 17 | hilo
# Processing Record 133 of Set 17 | ponta do sol
# Processing Record 134 of Set 17 | bambous virieux
# Processing Record 135 of Set 17 | sao filipe
# Processing Record 136 of Set 17 | aflu
# City:aflu was not found. | Retrieving data for next entry.
# Processing Record 137 of Set 18 | puerto escondido
# Processing Record 138 of Set 18 | tasiilaq
# Processing Record 139 of Set 18 | thompson
# Processing Record 140 of Set 18 | carnarvon
# Processing Record 141 of Set 18 | antalaha
# Processing Record 142 of Set 18 | longyearbyen
# Processing Record 143 of Set 18 | taolanaro
# City:taolanaro was not found. | Retrieving data for next entry.
# Processing Record 144 of Set 19 | port lincoln
# Processing Record 145 of Set 19 | zhigalovo
# Processing Record 146 of Set 19 | anju
# Processing Record 147 of Set 19 | taksimo
# Processing Record 148 of Set 19 | fasa
# Processing Record 149 of Set 19 | kendari
# Processing Record 150 of Set 19 | cansancao
# City:cansancao was not found. | Retrieving data for next entry.
# Processing Record 151 of Set 20 | bredasdorp
# Processing Record 152 of Set 20 | lebu
# Processing Record 153 of Set 20 | vestmannaeyjar
# Processing Record 154 of Set 20 | tiarei
# Processing Record 155 of Set 20 | asau
# City:asau was not found. | Retrieving data for next entry.
# Processing Record 156 of Set 21 | baykit
# Processing Record 157 of Set 21 | port augusta
# Processing Record 158 of Set 21 | atambua
# Processing Record 159 of Set 21 | kaitangata
# Processing Record 160 of Set 21 | sayyan
# Processing Record 161 of Set 21 | khakhea
# Processing Record 162 of Set 21 | kaeo
# Processing Record 163 of Set 21 | batemans bay
# Processing Record 164 of Set 21 | bengkulu
# City:bengkulu was not found. | Retrieving data for next entry.
# Processing Record 165 of Set 22 | macaboboni
# City:macaboboni was not found. | Retrieving data for next entry.
# Processing Record 166 of Set 23 | ngukurr
# City:ngukurr was not found. | Retrieving data for next entry.
# Processing Record 167 of Set 24 | sentyabrskiy
# City:sentyabrskiy was not found. | Retrieving data for next entry.
# Processing Record 168 of Set 25 | jeremie
# Processing Record 169 of Set 25 | leningradskiy
# Processing Record 170 of Set 25 | port blair
# Processing Record 171 of Set 25 | attawapiskat
# City:attawapiskat was not found. | Retrieving data for next entry.
# Processing Record 172 of Set 26 | puerto ayora
# Processing Record 173 of Set 26 | chorozinho
# Processing Record 174 of Set 26 | chuy
# Processing Record 175 of Set 26 | yumen
# Processing Record 176 of Set 26 | kayerkan
# Processing Record 177 of Set 26 | puerto del rosario
# Processing Record 178 of Set 26 | haines junction
# Processing Record 179 of Set 26 | maniitsoq
# Processing Record 180 of Set 26 | betsiamites
# Processing Record 181 of Set 26 | verkhoyansk
# Processing Record 182 of Set 26 | olafsvik
# City:olafsvik was not found. | Retrieving data for next entry.
# Processing Record 183 of Set 27 | sambava
# Processing Record 184 of Set 27 | adrar
# Processing Record 185 of Set 27 | bintulu
# Processing Record 186 of Set 27 | khonuu
# City:khonuu was not found. | Retrieving data for next entry.
# Processing Record 187 of Set 28 | asfi
# City:asfi was not found. | Retrieving data for next entry.
# Processing Record 188 of Set 29 | saskylakh
# Processing Record 189 of Set 29 | belyy
# Processing Record 190 of Set 29 | port elizabeth
# Processing Record 191 of Set 29 | saint-louis
# Processing Record 192 of Set 29 | huarmey
# Processing Record 193 of Set 29 | morgan city
# Processing Record 194 of Set 29 | turayf
# Processing Record 195 of Set 29 | mopipi
# Processing Record 196 of Set 29 | shiyan
# Processing Record 197 of Set 29 | bardiyah
# City:bardiyah was not found. | Retrieving data for next entry.
# Processing Record 198 of Set 30 | waipawa
# Processing Record 199 of Set 30 | maonon
# Processing Record 200 of Set 30 | mantua
# Processing Record 201 of Set 30 | morant bay
# Processing Record 202 of Set 30 | aloleng
# Processing Record 203 of Set 30 | labuhan
# Processing Record 204 of Set 30 | stromness
# Processing Record 205 of Set 30 | santa lucia
# Processing Record 206 of Set 30 | umzimvubu
# City:umzimvubu was not found. | Retrieving data for next entry.
# Processing Record 207 of Set 31 | tiksi
# Processing Record 208 of Set 31 | mount gambier
# Processing Record 209 of Set 31 | beyneu
# Processing Record 210 of Set 31 | honningsvag
# Processing Record 211 of Set 31 | danane
# Processing Record 212 of Set 31 | lagoa
# Processing Record 213 of Set 31 | keratea
# Processing Record 214 of Set 31 | srandakan
# Processing Record 215 of Set 31 | yeppoon
# Processing Record 216 of Set 31 | camargo
# Processing Record 217 of Set 31 | plaster rock
# Processing Record 218 of Set 31 | borama
# City:borama was not found. | Retrieving data for next entry.
# Processing Record 219 of Set 32 | wainwright
# Processing Record 220 of Set 32 | san cristobal
# Processing Record 221 of Set 32 | margate
# Processing Record 222 of Set 32 | lovozero
# Processing Record 223 of Set 32 | dingle
# Processing Record 224 of Set 32 | xichang
# Processing Record 225 of Set 32 | farafangana
# Processing Record 226 of Set 32 | vila franca do campo
# Processing Record 227 of Set 32 | aykhal
# Processing Record 228 of Set 32 | natal
# Processing Record 229 of Set 32 | katsuura
# Processing Record 230 of Set 32 | nizhneyansk
# City:nizhneyansk was not found. | Retrieving data for next entry.
# Processing Record 231 of Set 33 | wajima
# Processing Record 232 of Set 33 | grindavik
# Processing Record 233 of Set 33 | neumunster
# Processing Record 234 of Set 33 | nyamuswa
# Processing Record 235 of Set 33 | lavrentiya
# Processing Record 236 of Set 33 | laje
# Processing Record 237 of Set 33 | butaritari
# Processing Record 238 of Set 33 | elliot lake
# Processing Record 239 of Set 33 | kalmunai
# Processing Record 240 of Set 33 | rungata
# City:rungata was not found. | Retrieving data for next entry.
# Processing Record 241 of Set 34 | orocue
# Processing Record 242 of Set 34 | necochea
# Processing Record 243 of Set 34 | samusu
# City:samusu was not found. | Retrieving data for next entry.
# Processing Record 244 of Set 35 | maykain
# City:maykain was not found. | Retrieving data for next entry.
# Processing Record 245 of Set 36 | san rafael
# Processing Record 246 of Set 36 | suntar
# Processing Record 247 of Set 36 | sioux lookout
# Processing Record 248 of Set 36 | algeciras
# Processing Record 249 of Set 36 | shimoda
# Processing Record 250 of Set 36 | klaksvik
# Processing Record 251 of Set 36 | sao joao da barra
# Processing Record 252 of Set 36 | boshnyakovo
# Processing Record 253 of Set 36 | fuxin
# Processing Record 254 of Set 36 | palmer
# Processing Record 255 of Set 36 | solnechnyy
# Processing Record 256 of Set 36 | kelo
# City:kelo was not found. | Retrieving data for next entry.
# Processing Record 257 of Set 37 | kamina
# Processing Record 258 of Set 37 | udachnyy
# Processing Record 259 of Set 37 | tabou
# Processing Record 260 of Set 37 | mys shmidta
# City:mys shmidta was not found. | Retrieving data for next entry.
# Processing Record 261 of Set 38 | vila velha
# Processing Record 262 of Set 38 | avera
# Processing Record 263 of Set 38 | los llanos de aridane
# Processing Record 264 of Set 38 | kruisfontein
# Processing Record 265 of Set 38 | kenai
# Processing Record 266 of Set 38 | teeli
# Processing Record 267 of Set 38 | sakhipur
# Processing Record 268 of Set 38 | cabo san lucas
# Processing Record 269 of Set 38 | ahipara
# Processing Record 270 of Set 38 | hailar
# Processing Record 271 of Set 38 | stolin
# Processing Record 272 of Set 38 | saint-joseph
# Processing Record 273 of Set 38 | razole
# Processing Record 274 of Set 38 | whyalla
# Processing Record 275 of Set 38 | ilulissat
# Processing Record 276 of Set 38 | aliaga
# Processing Record 277 of Set 38 | roma
# Processing Record 278 of Set 38 | tabiauea
# City:tabiauea was not found. | Retrieving data for next entry.
# Processing Record 279 of Set 39 | krasnoborsk
# Processing Record 280 of Set 39 | rawson
# Processing Record 281 of Set 39 | chapais
# Processing Record 282 of Set 39 | college
# Processing Record 283 of Set 39 | rio tuba
# Processing Record 284 of Set 39 | kinsale
# Processing Record 285 of Set 39 | arauca
# Processing Record 286 of Set 39 | san jeronimo
# Processing Record 287 of Set 39 | monrovia
# Processing Record 288 of Set 39 | grand gaube
# Processing Record 289 of Set 39 | yenagoa
# Processing Record 290 of Set 39 | mnogovershinnyy
# Processing Record 291 of Set 39 | basse
# Processing Record 292 of Set 39 | tocache
# Processing Record 293 of Set 39 | coquimbo
# Processing Record 294 of Set 39 | biak
# Processing Record 295 of Set 39 | pacifica
# Processing Record 296 of Set 39 | esperance
# Processing Record 297 of Set 39 | cururupu
# Processing Record 298 of Set 39 | sandakan
# Processing Record 299 of Set 39 | edgewater
# Processing Record 300 of Set 39 | codrington
# Processing Record 301 of Set 39 | mariestad
# Processing Record 302 of Set 39 | narsaq
# Processing Record 303 of Set 39 | correderos
# Processing Record 304 of Set 39 | dwarka
# Processing Record 305 of Set 39 | tsihombe
# City:tsihombe was not found. | Retrieving data for next entry.
# Processing Record 306 of Set 40 | kracheh
# City:kracheh was not found. | Retrieving data for next entry.
# Processing Record 307 of Set 41 | vung tau
# Processing Record 308 of Set 41 | tura
# Processing Record 309 of Set 41 | ongwediva
# Processing Record 310 of Set 41 | gravdal
# Processing Record 311 of Set 41 | ishigaki
# Processing Record 312 of Set 41 | jinxiang
# Processing Record 313 of Set 41 | marsa matruh
# Processing Record 314 of Set 41 | usinsk
# Processing Record 315 of Set 41 | meadow lake
# Processing Record 316 of Set 41 | skrunda
# Processing Record 317 of Set 41 | rio cuarto
# Processing Record 318 of Set 41 | satitoa
# City:satitoa was not found. | Retrieving data for next entry.
# Processing Record 319 of Set 42 | pushkino
# Processing Record 320 of Set 42 | fare
# Processing Record 321 of Set 42 | hobyo
# Processing Record 322 of Set 42 | upington
# Processing Record 323 of Set 42 | kokopo
# Processing Record 324 of Set 42 | carndonagh
# Processing Record 325 of Set 42 | nuuk
# Processing Record 326 of Set 42 | elat
# Processing Record 327 of Set 42 | tuatapere
# Processing Record 328 of Set 42 | cherskiy
# Processing Record 329 of Set 42 | ngunguru
# Processing Record 330 of Set 42 | verkhnyaya toyma
# Processing Record 331 of Set 42 | faya
# Processing Record 332 of Set 42 | pimentel
# Processing Record 333 of Set 42 | zaraza
# Processing Record 334 of Set 42 | makakilo city
# Processing Record 335 of Set 42 | touros
# Processing Record 336 of Set 42 | awjilah
# Processing Record 337 of Set 42 | areosa
# Processing Record 338 of Set 42 | maunabo
# Processing Record 339 of Set 42 | druskininkai
# Processing Record 340 of Set 42 | mazagao
# Processing Record 341 of Set 42 | anadyr
# Processing Record 342 of Set 42 | atasu
# Processing Record 343 of Set 42 | mananjary
# Processing Record 344 of Set 42 | hakkari
# Processing Record 345 of Set 42 | igrim
# Processing Record 346 of Set 42 | mildura
# Processing Record 347 of Set 42 | madimba
# Processing Record 348 of Set 42 | tosno
# Processing Record 349 of Set 42 | lexington
# Processing Record 350 of Set 42 | alofi
# Processing Record 351 of Set 42 | kismayo
# City:kismayo was not found. | Retrieving data for next entry.
# Processing Record 352 of Set 43 | florianopolis
# Processing Record 353 of Set 43 | liancheng
# Processing Record 354 of Set 43 | manokwari
# Processing Record 355 of Set 43 | kamenskoye
# City:kamenskoye was not found. | Retrieving data for next entry.
# Processing Record 356 of Set 44 | taoudenni
# Processing Record 357 of Set 44 | mbacke
# City:mbacke was not found. | Retrieving data for next entry.
# Processing Record 358 of Set 45 | akyab
# City:akyab was not found. | Retrieving data for next entry.
# Processing Record 359 of Set 46 | talnakh
# Processing Record 360 of Set 46 | tidore
# City:tidore was not found. | Retrieving data for next entry.
# Processing Record 361 of Set 47 | okhotsk
# Processing Record 362 of Set 47 | flinders
# Processing Record 363 of Set 47 | dunedin
# Processing Record 364 of Set 47 | parana
# Processing Record 365 of Set 47 | ulagan
# Processing Record 366 of Set 47 | vardo
# Processing Record 367 of Set 47 | gamba
# Processing Record 368 of Set 47 | pevek
# Processing Record 369 of Set 47 | praia da vitoria
# Processing Record 370 of Set 47 | ipora
# City:ipora was not found. | Retrieving data for next entry.
# Processing Record 371 of Set 48 | kamaishi
# Processing Record 372 of Set 48 | cayenne
# Processing Record 373 of Set 48 | mehamn
# Processing Record 374 of Set 48 | anar darreh
# City:anar darreh was not found. | Retrieving data for next entry.
# Processing Record 375 of Set 49 | paita
# Processing Record 376 of Set 49 | birao
# Processing Record 377 of Set 49 | karratha
# Processing Record 378 of Set 49 | coihaique
# Processing Record 379 of Set 49 | souris
# Processing Record 380 of Set 49 | mon
# Processing Record 381 of Set 49 | souillac
# Processing Record 382 of Set 49 | nabire
# Processing Record 383 of Set 49 | san jose
# Processing Record 384 of Set 49 | sahuaripa
# Processing Record 385 of Set 49 | balykshi
# City:balykshi was not found. | Retrieving data for next entry.
# Processing Record 386 of Set 50 | warrenton
# Processing Record 387 of Set 50 | nanortalik
# Processing Record 388 of Set 50 | burewala
# Processing Record 389 of Set 50 | jalu
# Processing Record 390 of Set 50 | altay
# Processing Record 391 of Set 50 | te anau
# Processing Record 392 of Set 50 | ilhabela
# Processing Record 393 of Set 50 | laguna
# Processing Record 394 of Set 50 | miyako
# Processing Record 395 of Set 50 | katobu
# Processing Record 396 of Set 50 | sangar
# Processing Record 397 of Set 50 | russell
# Processing Record 398 of Set 50 | busilac
# Processing Record 399 of Set 50 | fairbanks
# Processing Record 400 of Set 50 | korla
# City:korla was not found. | Retrieving data for next entry.
# Processing Record 401 of Set 51 | georgetown
# Processing Record 402 of Set 51 | merauke
# Processing Record 403 of Set 51 | beloha
# Processing Record 404 of Set 51 | manaure
# Processing Record 405 of Set 51 | vostok
# Processing Record 406 of Set 51 | saint-pierre
# Processing Record 407 of Set 51 | alice springs
# Processing Record 408 of Set 51 | boyolangu
# Processing Record 409 of Set 51 | rincon
# Processing Record 410 of Set 51 | ambilobe
# Processing Record 411 of Set 51 | oranjemund
# Processing Record 412 of Set 51 | kondinskoye
# Processing Record 413 of Set 51 | guerrero negro
# Processing Record 414 of Set 51 | kangaatsiaq
# Processing Record 415 of Set 51 | nome
# Processing Record 416 of Set 51 | australind
# Processing Record 417 of Set 51 | lolua
# City:lolua was not found. | Retrieving data for next entry.
# Processing Record 418 of Set 52 | jaru
# Processing Record 419 of Set 52 | sharjah
# Processing Record 420 of Set 52 | guarapari
# Processing Record 421 of Set 52 | tevriz
# Processing Record 422 of Set 52 | deqing
# Processing Record 423 of Set 52 | ohangaron
# Processing Record 424 of Set 52 | manzil salim
# Processing Record 425 of Set 52 | tabas
# Processing Record 426 of Set 52 | matadi
# Processing Record 427 of Set 52 | atar
# Processing Record 428 of Set 52 | saryshagan
# City:saryshagan was not found. | Retrieving data for next entry.
# Processing Record 429 of Set 53 | najran
# Processing Record 430 of Set 53 | sosva
# Processing Record 431 of Set 53 | luvianos
# Processing Record 432 of Set 53 | portachuelo
# Processing Record 433 of Set 53 | batagay-alyta
# Processing Record 434 of Set 53 | hofn
# Processing Record 435 of Set 53 | lima
# Processing Record 436 of Set 53 | saleaula
# City:saleaula was not found. | Retrieving data for next entry.
# Processing Record 437 of Set 54 | seoul
# Processing Record 438 of Set 54 | shawnee
# Processing Record 439 of Set 54 | kulachi
# Processing Record 440 of Set 54 | oskemen
# Processing Record 441 of Set 54 | tres arroyos
# Processing Record 442 of Set 54 | mahebourg
# Processing Record 443 of Set 54 | ontario
# Processing Record 444 of Set 54 | mahibadhoo
# Processing Record 445 of Set 54 | halalo
# City:halalo was not found. | Retrieving data for next entry.
# Processing Record 446 of Set 55 | springville
# Processing Record 447 of Set 55 | nushki
# Processing Record 448 of Set 55 | leh
# Processing Record 449 of Set 55 | sal rei
# Processing Record 450 of Set 55 | olinda
# Processing Record 451 of Set 55 | miramar
# Processing Record 452 of Set 55 | sorland
# Processing Record 453 of Set 55 | sulangan
# Processing Record 454 of Set 55 | hirado
# Processing Record 455 of Set 55 | waitati
# Processing Record 456 of Set 55 | sooke
# Processing Record 457 of Set 55 | guozhen
# Processing Record 458 of Set 55 | conde
# Processing Record 459 of Set 55 | mana
# Processing Record 460 of Set 55 | okha
# Processing Record 461 of Set 55 | magog
# Processing Record 462 of Set 55 | marzuq
# Processing Record 463 of Set 55 | kavaratti
# Processing Record 464 of Set 55 | constitucion
# Processing Record 465 of Set 55 | ostrogozhsk
# Processing Record 466 of Set 55 | novobureyskiy
# Processing Record 467 of Set 55 | caconda
# Processing Record 468 of Set 55 | nioro
# Processing Record 469 of Set 55 | onega
# Processing Record 470 of Set 55 | catalina
# Processing Record 471 of Set 55 | kalmar
# Processing Record 472 of Set 55 | roald
# Processing Record 473 of Set 55 | toppenish
# Processing Record 474 of Set 55 | poum
# Processing Record 475 of Set 55 | fortuna
# Processing Record 476 of Set 55 | grimshaw
# Processing Record 477 of Set 55 | arcata
# Processing Record 478 of Set 55 | high rock
# Processing Record 479 of Set 55 | deputatskiy
# Processing Record 480 of Set 55 | crotone
# Processing Record 481 of Set 55 | kavieng
# Processing Record 482 of Set 55 | chengannur
# Processing Record 483 of Set 55 | jiehu
# Processing Record 484 of Set 55 | kalaleh
# Processing Record 485 of Set 55 | rangapara
# Processing Record 486 of Set 55 | port huron
# Processing Record 487 of Set 55 | nizwa
# Processing Record 488 of Set 55 | antsohihy
# Processing Record 489 of Set 55 | singaparna
# Processing Record 490 of Set 55 | radchenko
# Processing Record 491 of Set 55 | comodoro rivadavia
# Processing Record 492 of Set 55 | myitkyina
# Processing Record 493 of Set 55 | bangassou
# Processing Record 494 of Set 55 | tacuati
# Processing Record 495 of Set 55 | koumac
# Processing Record 496 of Set 55 | bajo baudo
# City:bajo baudo was not found. | Retrieving data for next entry.
# Processing Record 497 of Set 56 | yulara
# Processing Record 498 of Set 56 | teahupoo
# Processing Record 499 of Set 56 | tromso
# Processing Record 500 of Set 56 | acapulco
# Processing Record 501 of Set 56 | aporawan
# City:aporawan was not found. | Retrieving data for next entry.
# Processing Record 502 of Set 57 | daxian
# City:daxian was not found. | Retrieving data for next entry.
# Processing Record 503 of Set 58 | otofuke
# Processing Record 504 of Set 58 | trelew
# Processing Record 505 of Set 58 | otane
# Processing Record 506 of Set 58 | markala
# Processing Record 507 of Set 58 | oil city
# Processing Record 508 of Set 58 | xiongzhou
# Processing Record 509 of Set 58 | sisimiut
# Processing Record 510 of Set 58 | omsukchan
# Processing Record 511 of Set 58 | mahanoro
# Processing Record 512 of Set 58 | yomou
# Processing Record 513 of Set 58 | buala
# Processing Record 514 of Set 58 | wattegama
# Processing Record 515 of Set 58 | pacific grove
# Processing Record 516 of Set 58 | thouars
# Processing Record 517 of Set 58 | sydney
# Processing Record 518 of Set 58 | murray bridge
# Processing Record 519 of Set 58 | calama
# Processing Record 520 of Set 58 | bilma
# Processing Record 521 of Set 58 | salalah
# Processing Record 522 of Set 58 | liwale
# Processing Record 523 of Set 58 | hokitika
# Processing Record 524 of Set 58 | hasaki
# Processing Record 525 of Set 58 | kalugumalai
# Processing Record 526 of Set 58 | rostaq
# City:rostaq was not found. | Retrieving data for next entry.
# Processing Record 527 of Set 59 | cabinda
# Processing Record 528 of Set 59 | sistranda
# Processing Record 529 of Set 59 | buin
# Processing Record 530 of Set 59 | muzaffarpur
# Processing Record 531 of Set 59 | bogo
# Processing Record 532 of Set 59 | tete
# Processing Record 533 of Set 59 | surenavan
# Processing Record 534 of Set 59 | nacunday
# City:nacunday was not found. | Retrieving data for next entry.
# Processing Record 535 of Set 60 | bad freienwalde
# Processing Record 536 of Set 60 | rio grande
# Processing Record 537 of Set 60 | srednekolymsk
# Processing Record 538 of Set 60 | torbay
# Processing Record 539 of Set 60 | charagua
# Processing Record 540 of Set 60 | kankan
# Processing Record 541 of Set 60 | bargal
# City:bargal was not found. | Retrieving data for next entry.
# Processing Record 542 of Set 61 | montecristo
# Processing Record 543 of Set 61 | sotnikovo
# Processing Record 544 of Set 61 | pangkalanbuun
# Processing Record 545 of Set 61 | nam som
# Processing Record 546 of Set 61 | port hardy
# Processing Record 547 of Set 61 | belyy yar
# Processing Record 548 of Set 61 | rio gallegos
# Processing Record 549 of Set 61 | general roca
# Processing Record 550 of Set 61 | pangnirtung
# Processing Record 551 of Set 61 | coria
# Processing Record 552 of Set 61 | vayia
# City:vayia was not found. | Retrieving data for next entry.
# Processing Record 553 of Set 62 | balabac
# Processing Record 554 of Set 62 | whithorn
# Processing Record 555 of Set 62 | chase
# Processing Record 556 of Set 62 | hay river
# Processing Record 557 of Set 62 | samalaeulu
# City:samalaeulu was not found. | Retrieving data for next entry.
# Processing Record 558 of Set 63 | mmabatho
# Processing Record 559 of Set 63 | inhambane
# Processing Record 560 of Set 63 | amguri
# Processing Record 561 of Set 63 | fuerte olimpo
# Processing Record 562 of Set 63 | gulshat
# City:gulshat was not found. | Retrieving data for next entry.
# Processing Record 563 of Set 64 | centralia
# Processing Record 564 of Set 64 | krasnovishersk
# Processing Record 565 of Set 64 | praia
# Processing Record 566 of Set 64 | ludvika
# Processing Record 567 of Set 64 | taikang
# Processing Record 568 of Set 64 | samana
# Processing Record 569 of Set 64 | namatanai
# Processing Record 570 of Set 64 | hlotse
# City:hlotse was not found. | Retrieving data for next entry.
# Processing Record 571 of Set 65 | half moon bay
# Processing Record 572 of Set 65 | ponta delgada
# Processing Record 573 of Set 65 | kautokeino
# Processing Record 574 of Set 65 | myrtle beach
# Processing Record 575 of Set 65 | puro
# Processing Record 576 of Set 65 | kalmanka
# Processing Record 577 of Set 65 | verkhnyaya inta
# Processing Record 578 of Set 65 | hualmay
# Processing Record 579 of Set 65 | maghama
# City:maghama was not found. | Retrieving data for next entry.
# Processing Record 580 of Set 66 | san andres
# Processing Record 581 of Set 66 | port lavaca
# Processing Record 582 of Set 66 | sao jose da coroa grande
# Processing Record 583 of Set 66 | mitsamiouli
# Processing Record 584 of Set 66 | nam tha
# City:nam tha was not found. | Retrieving data for next entry.
# Processing Record 585 of Set 67 | panagjuriste
# City:panagjuriste was not found. | Retrieving data for next entry.
# Processing Record 586 of Set 68 | madingou
# Processing Record 587 of Set 68 | padilla
# Processing Record 588 of Set 68 | naas
# Processing Record 589 of Set 68 | basco
# Processing Record 590 of Set 68 | hamilton
# Processing Record 591 of Set 68 | altoona
# Processing Record 592 of Set 68 | cairns
# Processing Record 593 of Set 68 | saint-francois
# Processing Record 594 of Set 68 | pakwach
# City:pakwach was not found. | Retrieving data for next entry.
# Processing Record 595 of Set 69 | nha trang
# Processing Record 596 of Set 69 | urumqi
# City:urumqi was not found. | Retrieving data for next entry.
# Processing Record 597 of Set 70 | tezu
# Processing Record 598 of Set 70 | mercedes
# Processing Record 599 of Set 70 | mokrous
# Processing Record 600 of Set 70 | calvinia
# Processing Record 601 of Set 70 | umm lajj
# Processing Record 602 of Set 70 | bilibino
# Processing Record 603 of Set 70 | portpatrick
# City:portpatrick was not found. | Retrieving data for next entry.
# Processing Record 604 of Set 71 | kutum
# Processing Record 605 of Set 71 | kovur
# Processing Record 606 of Set 71 | ocos
# Processing Record 607 of Set 71 | cruzeiro do sul
# --------------------------
# Data Retrieval is Complete
# --------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
summary = citydata.count()
summary
# Out:
# City          537
# Cloudiness    537
# Country       537
# Date          537
# Humidity      537
# Lat           537
# Lng           537
# Max Temp      537
# Wind Speed    537
# dtype: int64

# %%
citydata = pd.DataFrame(citydict)
citydata.to_csv("/Users/kurtshiple/Desktop/UNCBootcampLocalHWFolders/Homework6:API/final/cityweatherdata.csv", encoding='utf-8', index=False)
citydata.head(20)
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Sokolka          92      RU  1552662550        89  52.46   43.89
# 1       Ushuaia           0      AR  1552658400        51 -54.81  -68.31
# 2        Faanui          48      PF  1552662552       100 -16.48 -151.75
# 3       Kahului           1      US  1552662095        73  20.89 -156.47
# 4        Moerai          64      PF  1552662555       100 -22.43 -151.33
# 5     Dungarpur           0      IN  1552662870        31  23.85   73.71
# 6     Tilichiki           0      RU  1552662871        39  60.47  166.10
# 7   Clyde River          75      CA  1552658400        83  70.47  -68.59
# 8     Hithadhoo          92      MV  1552662874       100  -0.60   73.08
# 9    Porto Novo          75      BR  1552658400        73 -23.68  -45.44
# 10        Asyut           0      EG  1552658400        25  27.18   31.19
# 11  Tuktoyaktuk          40      CA  1552658400        77  69.44 -133.03
# 12   Las Palmas          75      PE  1552658400       290  -6.53  -76.35
# 13        Bluff          92      AU  1552662880        99 -23.58  149.07
# 14   Nikolskoye          75      RU  1552662791        91  59.70   30.79
# 15      Iqaluit          90      CA  1552658400        64  63.75  -68.52
# 16      Mataura           0      NZ  1552662604        92 -46.19  168.86
# 17       Bonfim          40      BR  1552658400        45 -20.33  -44.24
# 18  Bracebridge          90      CA  1552662857        93  45.04  -79.31
# 19  Port Alfred          68      ZA  1552662621        94 -33.59   26.89
#
#     Max Temp  Wind Speed
# 0      28.00       10.11
# 1      59.00       13.87
# 2      82.27        5.19
# 3      69.80        4.70
# 4      79.12       24.54
# 5      73.36        8.55
# 6     -26.45        2.62
# 7     -11.21        6.93
# 8      83.98        6.64
# 9      77.00        4.70
# 10     73.40       11.41
# 11      3.20       12.75
# 12     62.60        2.24
# 13     67.33        5.64
# 14     37.99       13.42
# 15     -2.21        3.36
# 16     48.99        3.51
# 17     86.00        4.70
# 18     39.99       11.41
# 19     75.00        4.00

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build the scatter plots for each city types
citylatvsmaxtemp = plt.scatter(citydata["Lat"], citydata["Max Temp"], marker="o", c = "red",
                              edgecolors="black", alpha=0.45, linewidths= 2)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (08/23/18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()



# Save Figure

plt.tight_layout()
plt.savefig("/Users/kurtshiple/Desktop/UNCBootcampLocalHWFolders/Homework6:API/final/citylatvsmaxtemp",bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for each city types
citylatvshumidity = plt.scatter(citydata["Lat"], citydata["Humidity"], marker="o", c = "red",
                              edgecolors="black", alpha=0.45, linewidths= 2)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (08/23/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()


# Save Figure

plt.tight_layout()
plt.savefig("/Users/kurtshiple/Desktop/UNCBootcampLocalHWFolders/Homework6:API/final/citylatvshumidity",bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for each city types
citylatvshumidity = plt.scatter(citydata["Lat"], citydata["Cloudiness"], marker="o", c = "red",
                              edgecolors="black", alpha=0.45, linewidths= 2)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (08/23/18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()



# Save Figure

plt.tight_layout()
plt.savefig("/Users/kurtshiple/Desktop/UNCBootcampLocalHWFolders/Homework6:API/final/citylatvscloudiness",bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for each city types
citylatvshumidity = plt.scatter(citydata["Lat"], citydata["Wind Speed"], marker="o", c = "red",
                              edgecolors="black", alpha=0.45, linewidths= 2)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (08/23/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()


# Save Figure

plt.tight_layout()
plt.savefig("/Users/kurtshiple/Desktop/UNCBootcampLocalHWFolders/Homework6:API/final/citylatvswindspeed",bbox_inches='tight')
plt.show()
